# %% [markdown]
# ## Eigene Umgebung

# %%
import gymnasium as gym
import numpy as np
from gymnasium.spaces import Discrete, Box
from typing import Optional

# %% [markdown]
# ### Typen von Spaces
#
# Action/Observation Space haben jeweils einen Typen

# %%
Discrete(3)  # Einzelne Zahl von 0 bis X
# Out:
# Discrete(3)

# %%
b = Box(0, 10, dtype=np.float32, shape=(4,))

# %%
b.sample()
# Out:
# array([2.11341  , 5.20718  , 7.8557796, 5.66286  ], dtype=float32)

# %% [markdown]
# ### Eigene Umgebung definieren
#
# Autofahrer
#
# Soll immer zw. 45km/h und 55km/h fahren
#
# Drei Actions: Bremsen, Beschleunigen, Nichts
#
# Observations: Derzeitige Geschwindigkeit
#
# Wenn die AktV >= 45 <= 50 ist, soll eine Belohnung ausgeschüttet werden
#
# State: Derzeitige Geschwindigkeit

# %%
class CarDriver(gym.Env):
    def __init__(self):
        self.action_space = Discrete(3)  # 3 Aktionen, 0: Nichts tun, 1: Bremsen, 2: Beschleunigen
        self.observation_space = Box(0, 100, dtype=np.int8)
        self.state = 50
        self.driveLength = 60
    
    def step(self, action):
        if action == 1:
            self.state -= 3
        elif action == 2:
            self.state += 3

        # Random Noise
        self.state += np.random.randint(3) - 1

        if self.state >= 45 and self.state <= 55:
            reward = 1
        else:
            reward = 0

        self.driveLength -= 1

        return np.array([self.state], dtype=np.int8), reward, self.driveLength <= 0, False, {}

    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None):
        self.state = 50
        self.driveLength = 60
        return (np.array([self.state], dtype=np.int8), {})

# %%
from stable_baselines3.common.env_checker import check_env

# %%
env = CarDriver()

# %%
check_env(env, warn=True)

# %% [markdown]
# ### Testen

# %%
d = 5
for x in range(d):
    start = env.reset()
    score = 0
    done = False
    
    while not done:
        # env.render()  # Umgebung zeichnen
        action = env.action_space.sample()  # Generiere eine Random Action
        newState, reward, done, term, info = env.step(action)  # Bei einer Action kommen 5 Werte zurück: Neuer State, Belohnung, Fertig?, Mach Ende?, Info
        score += reward
    print(f"Durchgang: {x}, Score: {score}")
# env.close()
# Out:
# Durchgang: 0, Score: 5
# Durchgang: 1, Score: 54
# Durchgang: 2, Score: 16
# Durchgang: 3, Score: 9
# Durchgang: 4, Score: 2

# %% [markdown]
# ### Lernen/Trainieren

# %%
from stable_baselines3 import PPO

# %%
env = CarDriver()

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 23.4     |
# | time/              |          |
# |    fps             | 667      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 22.8        |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008014955 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0012     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.63        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.002      |
# |    value_loss           | 18.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 22.1         |
# | time/                   |              |
# |    fps                  | 286          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0058863275 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.029       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.79         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 19.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 22.3         |
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 4            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0017555216 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0312       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.44         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00485     |
# |    value_loss           | 21.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 23.4       |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 5          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00705408 |
# |    clip_fraction        | 0.0643     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.117      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.29       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00609   |
# |    value_loss           | 25.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 27.1         |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 6            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0059217378 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.0415       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00564     |
# |    value_loss           | 29.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.7        |
# | time/                   |             |
# |    fps                  | 263         |
# |    iterations           | 7           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007076077 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0132     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 35.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 35.5        |
# | time/                   |             |
# |    fps                  | 265         |
# |    iterations           | 8           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005667733 |
# |    clip_fraction        | 0.0324      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.00943     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00384    |
# |    value_loss           | 37          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 38.3         |
# | time/                   |              |
# |    fps                  | 265          |
# |    iterations           | 9            |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0024006409 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.00722      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.1         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000711    |
# |    value_loss           | 49.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 39.6         |
# | time/                   |              |
# |    fps                  | 264          |
# |    iterations           | 10           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0018910589 |
# |    clip_fraction        | 0.0924       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0422       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.2         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00374     |
# |    value_loss           | 49.1         |
# ------------------------------------------

# %%
model.learn(total_timesteps=20_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 37.5     |
# | time/              |          |
# |    fps             | 805      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39.1        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008983763 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0459      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.7        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00916    |
# |    value_loss           | 52.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 38.9       |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 3          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00921626 |
# |    clip_fraction        | 0.121      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.0543     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38.8       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00935   |
# |    value_loss           | 56         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39.5        |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 4           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007612551 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0264     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0038     |
# |    value_loss           | 61.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41          |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010019865 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0138      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.5        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00142    |
# |    value_loss           | 59.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 41.4         |
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 6            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0063233264 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.00276     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.6         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 0.000819     |
# |    value_loss           | 60           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 42.8         |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 7            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0060569253 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.0128       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.4         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.000357     |
# |    value_loss           | 64.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 43.8         |
# | time/                   |              |
# |    fps                  | 279          |
# |    iterations           | 8            |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0052077854 |
# |    clip_fraction        | 0.0732       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.00828      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.7         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 64.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 44.3       |
# | time/                   |            |
# |    fps                  | 279        |
# |    iterations           | 9          |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00966243 |
# |    clip_fraction        | 0.0892     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | -0.00132   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.2       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.00208    |
# |    value_loss           | 68         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 10          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013476017 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.0135      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.2        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00438    |
# |    value_loss           | 71.8        |
# -----------------------------------------

# %%
model.learn(total_timesteps=50_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 49       |
# | time/              |          |
# |    fps             | 581      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.2        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013218502 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.0114      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.9        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.000192    |
# |    value_loss           | 75.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.1        |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011506574 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.00202    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.4        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00292     |
# |    value_loss           | 76.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.7        |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 4           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008694016 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.00221    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.2        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.000908    |
# |    value_loss           | 79.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 48.1         |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 5            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0060213255 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.00684      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.1         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0034      |
# |    value_loss           | 82           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.2        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 6           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009939758 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.0146     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41          |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00294     |
# |    value_loss           | 83.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.7        |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 7           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010730184 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.00224     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.9        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00334     |
# |    value_loss           | 84.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.3        |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 8           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005616369 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | 0.00672     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000659   |
# |    value_loss           | 87.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 49.2         |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 9            |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0049225115 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | 0.00281      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.8         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000245    |
# |    value_loss           | 86.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 48.6       |
# | time/                   |            |
# |    fps                  | 187        |
# |    iterations           | 10         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00200352 |
# |    clip_fraction        | 0.0697     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.918     |
# |    explained_variance   | 0.000692   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.1       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.00115    |
# |    value_loss           | 86.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 48.6         |
# | time/                   |              |
# |    fps                  | 183          |
# |    iterations           | 11           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0077856826 |
# |    clip_fraction        | 0.0921       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.00952      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.2         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.000446     |
# |    value_loss           | 85           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 49.7         |
# | time/                   |              |
# |    fps                  | 186          |
# |    iterations           | 12           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0041818013 |
# |    clip_fraction        | 0.0709       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.865       |
# |    explained_variance   | 0.0111       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.5         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.0013       |
# |    value_loss           | 85.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.2        |
# | time/                   |             |
# |    fps                  | 183         |
# |    iterations           | 13          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008653603 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.00907     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.9        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00272     |
# |    value_loss           | 89.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.2        |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 14          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.003820414 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.0059      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00286     |
# |    value_loss           | 89.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 52.5         |
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 15           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0021399895 |
# |    clip_fraction        | 0.0999       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.808       |
# |    explained_variance   | 0.00982      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.6         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.0028       |
# |    value_loss           | 90.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.2        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 16          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005950723 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.0165      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.9        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00162     |
# |    value_loss           | 98.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.3        |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 17          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009575615 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.762      |
# |    explained_variance   | -0.00515    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0174      |
# |    value_loss           | 92.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.8        |
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 18          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010348408 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | -0.00947    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.8        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00362     |
# |    value_loss           | 93          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.5        |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 19          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011533229 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 0.00755     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.9        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00137     |
# |    value_loss           | 94.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.2        |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 20          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.022778003 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.0457      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.6        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00159    |
# |    value_loss           | 85.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.1        |
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 21          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003952295 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.00143     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.8        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00614     |
# |    value_loss           | 96.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.9        |
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 22          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012444527 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.788      |
# |    explained_variance   | 0.0014      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00514     |
# |    value_loss           | 97.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.5        |
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 23          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010512123 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | 0.012       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66          |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00885     |
# |    value_loss           | 100         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 51.6         |
# | time/                   |              |
# |    fps                  | 199          |
# |    iterations           | 24           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0031550457 |
# |    clip_fraction        | 0.0851       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.71        |
# |    explained_variance   | 0.00651      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59           |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.00187      |
# |    value_loss           | 97.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.1        |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 25          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.021485304 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.0374      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.5        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00131     |
# |    value_loss           | 91.1        |
# -----------------------------------------

# %%
model.save("Models/CarDriver")

# %%
d = 5
for x in range(d):
    state = env.reset()  # [ 0.0492511 ,  0.04087935, -0.04937328, -0.00469788] (Startpos, StartV, StartPolePos, StartPoleV)
    score = 0
    done = False
    
    while not done:
        # env.render()  # Umgebung zeichnen
        if len(state) == 2:
            action, _ = model.predict(state[0])  # Generiere eine Random Action
        else:
            action, _ = model.predict(state)
        state, reward, done, term, info = env.step(action)  # Bei einer Action kommen 5 Werte zurück: Neuer State, Belohnung, Fertig?, Mach Ende?, Info
        score += reward
    print(f"Durchgang: {x}, Score: {score}")
# env.close()
# Out:
# Durchgang: 0, Score: 52
# Durchgang: 1, Score: 37
# Durchgang: 2, Score: 48
# Durchgang: 3, Score: 58
# Durchgang: 4, Score: 46
