# %% [markdown]
# ## Fehlerbehandlung mit Pandas
#
# Datensets haben oft Fehler, welche für die Analyse ausgebessert werden müssen
#
# z.B. Prozente, NaN, ...

# %%
import numpy as np
import pandas as pd

# %%
x = 5

# %%
pd.isnull(x)
# Out:
# False

# %%
pd.notnull(x)
# Out:
# True

# %%
data = pd.read_csv("Data/PopulationDataFastFertig.csv", index_col="Country")

# %%
data
# Out:
#                          Pop YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776       0.39 %    5540090      153  9388211
# India             1380004385       0.99 %   13586631      464  2973190
# United States      331002651       0.59 %    1937734       36  9147420
# Indonesia          273523615       1.07 %    2898047      151  1811570
# Pakistan           220892340       2.00 %    4327022      287   770880
# ...                      ...          ...        ...      ...      ...
# Montserrat              4992       0.06 %          3       50      100
# Falkland Islands        3480       3.05 %        103        0    12170
# Niue                    1626       0.68 %         11        6      260
# Tokelau                 1357       1.27 %         17      136       10
# Vatican State            801       0.25 %          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China            -348399.0       1.7      38     61 %    18.47 %
# India            -532687.0       2.2      28     35 %    17.70 %
# United States     954806.0       1.8      38     83 %     4.25 %
# Indonesia         -98955.0       2.3      30     56 %     3.51 %
# Pakistan         -233379.0       3.6      23     35 %     2.83 %
# ...                    ...       ...     ...      ...        ...
# Montserrat             NaN      N.A.    N.A.     10 %     0.00 %
# Falkland Islands       NaN      N.A.    N.A.     66 %     0.00 %
# Niue                   NaN      N.A.    N.A.     46 %     0.00 %
# Tokelau                NaN      N.A.    N.A.      0 %     0.00 %
# Vatican State          NaN      N.A.    N.A.     N.A.     0.00 %
#
# [235 rows x 10 columns]

# %%
pd.isnull(data)
# Out:
#                     Pop  YearlyChange  NetChange  Density   Area  Migrants  \
# Country
# China             False         False      False    False  False     False
# India             False         False      False    False  False     False
# United States     False         False      False    False  False     False
# Indonesia         False         False      False    False  False     False
# Pakistan          False         False      False    False  False     False
# ...                 ...           ...        ...      ...    ...       ...
# Montserrat        False         False      False    False  False      True
# Falkland Islands  False         False      False    False  False      True
# Niue              False         False      False    False  False      True
# Tokelau           False         False      False    False  False      True
# Vatican State     False         False      False    False  False      True
#
#                   Fert.Rate  Med.Age  UrbanPct  WorldShare
# Country
# China                 False    False     False       False
# India                 False    False     False       False
# United States         False    False     False       False
# Indonesia             False    False     False       False
# Pakistan              False    False     False       False
# ...                     ...      ...       ...         ...
# Montserrat            False    False     False       False
# Falkland Islands      False    False     False       False
# Niue                  False    False     False       False
# Tokelau               False    False     False       False
# Vatican State         False    False     False       False
#
# [235 rows x 10 columns]

# %% [markdown]
# ### Automatisches auffüllen von NaN

# %%
data.fillna(method="ffill")
# Out:
# C:\Users\lk3\AppData\Local\Temp\ipykernel_11312\2321864255.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="ffill")
#                          Pop YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776       0.39 %    5540090      153  9388211
# India             1380004385       0.99 %   13586631      464  2973190
# United States      331002651       0.59 %    1937734       36  9147420
# Indonesia          273523615       1.07 %    2898047      151  1811570
# Pakistan           220892340       2.00 %    4327022      287   770880
# ...                      ...          ...        ...      ...      ...
# Montserrat              4992       0.06 %          3       50      100
# Falkland Islands        3480       3.05 %        103        0    12170
# Niue                    1626       0.68 %         11        6      260
# Tokelau                 1357       1.27 %         17      136       10
# Vatican State            801       0.25 %          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China            -348399.0       1.7      38     61 %    18.47 %
# India            -532687.0       2.2      28     35 %    17.70 %
# United States     954806.0       1.8      38     83 %     4.25 %
# Indonesia         -98955.0       2.3      30     56 %     3.51 %
# Pakistan         -233379.0       3.6      23     35 %     2.83 %
# ...                    ...       ...     ...      ...        ...
# Montserrat             0.0      N.A.    N.A.     10 %     0.00 %
# Falkland Islands       0.0      N.A.    N.A.     66 %     0.00 %
# Niue                   0.0      N.A.    N.A.     46 %     0.00 %
# Tokelau                0.0      N.A.    N.A.      0 %     0.00 %
# Vatican State          0.0      N.A.    N.A.     N.A.     0.00 %
#
# [235 rows x 10 columns]

# %%
data.fillna(method="bfill")
# Out:
# C:\Users\lk3\AppData\Local\Temp\ipykernel_11312\1981131366.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="bfill")
#                          Pop YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776       0.39 %    5540090      153  9388211
# India             1380004385       0.99 %   13586631      464  2973190
# United States      331002651       0.59 %    1937734       36  9147420
# Indonesia          273523615       1.07 %    2898047      151  1811570
# Pakistan           220892340       2.00 %    4327022      287   770880
# ...                      ...          ...        ...      ...      ...
# Montserrat              4992       0.06 %          3       50      100
# Falkland Islands        3480       3.05 %        103        0    12170
# Niue                    1626       0.68 %         11        6      260
# Tokelau                 1357       1.27 %         17      136       10
# Vatican State            801       0.25 %          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China            -348399.0       1.7      38     61 %    18.47 %
# India            -532687.0       2.2      28     35 %    17.70 %
# United States     954806.0       1.8      38     83 %     4.25 %
# Indonesia         -98955.0       2.3      30     56 %     3.51 %
# Pakistan         -233379.0       3.6      23     35 %     2.83 %
# ...                    ...       ...     ...      ...        ...
# Montserrat             NaN      N.A.    N.A.     10 %     0.00 %
# Falkland Islands       NaN      N.A.    N.A.     66 %     0.00 %
# Niue                   NaN      N.A.    N.A.     46 %     0.00 %
# Tokelau                NaN      N.A.    N.A.      0 %     0.00 %
# Vatican State          NaN      N.A.    N.A.     N.A.     0.00 %
#
# [235 rows x 10 columns]

# %%
data.ffill(inplace=True)

# %%
data.bfill()
# Out:
#                          Pop YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776       0.39 %    5540090      153  9388211
# India             1380004385       0.99 %   13586631      464  2973190
# United States      331002651       0.59 %    1937734       36  9147420
# Indonesia          273523615       1.07 %    2898047      151  1811570
# Pakistan           220892340       2.00 %    4327022      287   770880
# ...                      ...          ...        ...      ...      ...
# Montserrat              4992       0.06 %          3       50      100
# Falkland Islands        3480       3.05 %        103        0    12170
# Niue                    1626       0.68 %         11        6      260
# Tokelau                 1357       1.27 %         17      136       10
# Vatican State            801       0.25 %          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China            -348399.0       1.7      38     61 %    18.47 %
# India            -532687.0       2.2      28     35 %    17.70 %
# United States     954806.0       1.8      38     83 %     4.25 %
# Indonesia         -98955.0       2.3      30     56 %     3.51 %
# Pakistan         -233379.0       3.6      23     35 %     2.83 %
# ...                    ...       ...     ...      ...        ...
# Montserrat             0.0      N.A.    N.A.     10 %     0.00 %
# Falkland Islands       0.0      N.A.    N.A.     66 %     0.00 %
# Niue                   0.0      N.A.    N.A.     46 %     0.00 %
# Tokelau                0.0      N.A.    N.A.      0 %     0.00 %
# Vatican State          0.0      N.A.    N.A.     N.A.     0.00 %
#
# [235 rows x 10 columns]

# %%
for col in data.isnull().columns:
    print(f"{col}: {len(data) - (data.isnull()[col] == True).value_counts()[False]}")
# Out:
# Pop: 0
# YearlyChange: 0
# NetChange: 0
# Density: 0
# Area: 0
# Migrants: 0
# Fert.Rate: 0
# Med.Age: 0
# UrbanPct: 0
# WorldShare: 0

# %% [markdown]
# ### NaN manuell beheben

# %%
x = data["Migrants"][data["Migrants"].isnull()]  # NaN in einer gegebenen Spalte finden

# %%
data.loc[x.index, "Migrants"] = 0  # NaN in der Spalte austauschen

# %%
def fixNaN(col: str, newValue):
    x = data[data[col].isnull()][col].index
    data.loc[x, col] = newValue

# %% [markdown]
# ### Weitere Schritte
#
# - Prozente
#
# - N.A.
#
# - Datentypen

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, China to Vatican State
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pop           235 non-null    int64
#  1   YearlyChange  235 non-null    object
#  2   NetChange     235 non-null    int64
#  3   Density       235 non-null    int64
#  4   Area          235 non-null    int64
#  5   Migrants      235 non-null    float64
#  6   Fert.Rate     235 non-null    object
#  7   Med.Age       235 non-null    object
#  8   UrbanPct      235 non-null    object
#  9   WorldShare    235 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 20.2+ KB

# %% [markdown]
# #### N.A.

# %%
data["Fert.Rate"] == "N.A."  # Bei einer Spalte N.A. finden
# Out:
# Country
# China               False
# India               False
# United States       False
# Indonesia           False
# Pakistan            False
#                     ...
# Montserrat           True
# Falkland Islands     True
# Niue                 True
# Tokelau              True
# Vatican State        True
# Name: Fert.Rate, Length: 235, dtype: bool

# %%
data[data["Fert.Rate"] == "N.A."]  # Datensätze mit N.A. filtern
# Out:
#                             Pop YearlyChange  NetChange  Density    Area  \
# Country
# Isle of Man               85033       0.53 %        449      149     570
# Andorra                   77265       0.16 %        123      164     470
# Dominica                  71986       0.25 %        178       96     750
# Cayman Islands            65722       1.19 %        774      274     240
# Bermuda                   62278      -0.36 %       -228     1246      50
# Marshall Islands          59190       0.68 %        399      329     180
# Northern Mariana Islands  57559       0.60 %        343      125     460
# Greenland                 56770       0.17 %         98        0  410450
# American Samoa            55191      -0.22 %       -121      276     200
# Saint Kitts & Nevis       53199       0.71 %        376      205     260
# Faeroe Islands            48863       0.38 %        185       35    1396
# Sint Maarten              42876       1.15 %        488     1261      34
# Monaco                    39242       0.71 %        278    26337       1
# Turks and Caicos          38717       1.38 %        526       41     950
# Saint Martin              38666       1.75 %        664      730      53
# Liechtenstein             38128       0.29 %        109      238     160
# San Marino                33931       0.21 %         71      566      60
# Gibraltar                 33691      -0.03 %        -10     3369      10
# British Virgin Islands    30231       0.67 %        201      202     150
# Caribbean Netherlands     26223       0.94 %        244       80     328
# Palau                     18094       0.48 %         86       39     460
# Cook Islands              17564       0.09 %         16       73     240
# Anguilla                  15003       0.90 %        134      167      90
# Tuvalu                    11792       1.25 %        146      393      30
# Wallis & Futuna           11239      -1.69 %       -193       80     140
# Nauru                     10824       0.63 %         68      541      20
# Saint Barthelemy           9877       0.30 %         30      470      21
# Saint Helena               6077       0.30 %         18       16     390
# Saint Pierre & Miquelon    5794      -0.48 %        -28       25     230
# Montserrat                 4992       0.06 %          3       50     100
# Falkland Islands           3480       3.05 %        103        0   12170
# Niue                       1626       0.68 %         11        6     260
# Tokelau                    1357       1.27 %         17      136      10
# Vatican State               801       0.25 %          2     2003       0
#
#                           Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# Isle of Man                    0.0      N.A.    N.A.     53 %     0.00 %
# Andorra                        0.0      N.A.    N.A.     88 %     0.00 %
# Dominica                       0.0      N.A.    N.A.     74 %     0.00 %
# Cayman Islands                 0.0      N.A.    N.A.     97 %     0.00 %
# Bermuda                        0.0      N.A.    N.A.     97 %     0.00 %
# Marshall Islands               0.0      N.A.    N.A.     70 %     0.00 %
# Northern Mariana Islands       0.0      N.A.    N.A.     88 %     0.00 %
# Greenland                      0.0      N.A.    N.A.     87 %     0.00 %
# American Samoa                 0.0      N.A.    N.A.     88 %     0.00 %
# Saint Kitts & Nevis            0.0      N.A.    N.A.     33 %     0.00 %
# Faeroe Islands                 0.0      N.A.    N.A.     43 %     0.00 %
# Sint Maarten                   0.0      N.A.    N.A.     96 %     0.00 %
# Monaco                         0.0      N.A.    N.A.     N.A.     0.00 %
# Turks and Caicos               0.0      N.A.    N.A.     89 %     0.00 %
# Saint Martin                   0.0      N.A.    N.A.      0 %     0.00 %
# Liechtenstein                  0.0      N.A.    N.A.     15 %     0.00 %
# San Marino                     0.0      N.A.    N.A.     97 %     0.00 %
# Gibraltar                      0.0      N.A.    N.A.     N.A.     0.00 %
# British Virgin Islands         0.0      N.A.    N.A.     52 %     0.00 %
# Caribbean Netherlands          0.0      N.A.    N.A.     75 %     0.00 %
# Palau                          0.0      N.A.    N.A.     N.A.     0.00 %
# Cook Islands                   0.0      N.A.    N.A.     75 %     0.00 %
# Anguilla                       0.0      N.A.    N.A.     N.A.     0.00 %
# Tuvalu                         0.0      N.A.    N.A.     62 %     0.00 %
# Wallis & Futuna                0.0      N.A.    N.A.      0 %     0.00 %
# Nauru                          0.0      N.A.    N.A.     N.A.     0.00 %
# Saint Barthelemy               0.0      N.A.    N.A.      0 %     0.00 %
# Saint Helena                   0.0      N.A.    N.A.     27 %     0.00 %
# Saint Pierre & Miquelon        0.0      N.A.    N.A.    100 %     0.00 %
# Montserrat                     0.0      N.A.    N.A.     10 %     0.00 %
# Falkland Islands               0.0      N.A.    N.A.     66 %     0.00 %
# Niue                           0.0      N.A.    N.A.     46 %     0.00 %
# Tokelau                        0.0      N.A.    N.A.      0 %     0.00 %
# Vatican State                  0.0      N.A.    N.A.     N.A.     0.00 %

# %%
data[data["Fert.Rate"] == "N.A."]["Fert.Rate"]
# Out:
# Country
# Isle of Man                 N.A.
# Andorra                     N.A.
# Dominica                    N.A.
# Cayman Islands              N.A.
# Bermuda                     N.A.
# Marshall Islands            N.A.
# Northern Mariana Islands    N.A.
# Greenland                   N.A.
# American Samoa              N.A.
# Saint Kitts & Nevis         N.A.
# Faeroe Islands              N.A.
# Sint Maarten                N.A.
# Monaco                      N.A.
# Turks and Caicos            N.A.
# Saint Martin                N.A.
# Liechtenstein               N.A.
# San Marino                  N.A.
# Gibraltar                   N.A.
# British Virgin Islands      N.A.
# Caribbean Netherlands       N.A.
# Palau                       N.A.
# Cook Islands                N.A.
# Anguilla                    N.A.
# Tuvalu                      N.A.
# Wallis & Futuna             N.A.
# Nauru                       N.A.
# Saint Barthelemy            N.A.
# Saint Helena                N.A.
# Saint Pierre & Miquelon     N.A.
# Montserrat                  N.A.
# Falkland Islands            N.A.
# Niue                        N.A.
# Tokelau                     N.A.
# Vatican State               N.A.
# Name: Fert.Rate, dtype: object

# %%
x = data[data["Fert.Rate"] == "N.A."]["Fert.Rate"]

# %%
data.loc[x.index, "Fert.Rate"] = 0

# %%
data
# Out:
#                          Pop YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776       0.39 %    5540090      153  9388211
# India             1380004385       0.99 %   13586631      464  2973190
# United States      331002651       0.59 %    1937734       36  9147420
# Indonesia          273523615       1.07 %    2898047      151  1811570
# Pakistan           220892340       2.00 %    4327022      287   770880
# ...                      ...          ...        ...      ...      ...
# Montserrat              4992       0.06 %          3       50      100
# Falkland Islands        3480       3.05 %        103        0    12170
# Niue                    1626       0.68 %         11        6      260
# Tokelau                 1357       1.27 %         17      136       10
# Vatican State            801       0.25 %          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China            -348399.0       1.7      38     61 %    18.47 %
# India            -532687.0       2.2      28     35 %    17.70 %
# United States     954806.0       1.8      38     83 %     4.25 %
# Indonesia         -98955.0       2.3      30     56 %     3.51 %
# Pakistan         -233379.0       3.6      23     35 %     2.83 %
# ...                    ...       ...     ...      ...        ...
# Montserrat             0.0         0    N.A.     10 %     0.00 %
# Falkland Islands       0.0         0    N.A.     66 %     0.00 %
# Niue                   0.0         0    N.A.     46 %     0.00 %
# Tokelau                0.0         0    N.A.      0 %     0.00 %
# Vatican State          0.0         0    N.A.     N.A.     0.00 %
#
# [235 rows x 10 columns]

# %%
def fixNA(col: str, newValue):
    x = data[data[col] == "N.A."][col].index  # Fehlerhafte Zeilen finden
    data.loc[x, col] = newValue  # Nimm alle Zeilen mit Fehlern, und schreibe newValue in jede Zeile hinein

# %%
fixNA("Med.Age", 0)

# %%
data
# Out:
#                          Pop YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776       0.39 %    5540090      153  9388211
# India             1380004385       0.99 %   13586631      464  2973190
# United States      331002651       0.59 %    1937734       36  9147420
# Indonesia          273523615       1.07 %    2898047      151  1811570
# Pakistan           220892340       2.00 %    4327022      287   770880
# ...                      ...          ...        ...      ...      ...
# Montserrat              4992       0.06 %          3       50      100
# Falkland Islands        3480       3.05 %        103        0    12170
# Niue                    1626       0.68 %         11        6      260
# Tokelau                 1357       1.27 %         17      136       10
# Vatican State            801       0.25 %          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China            -348399.0       1.7      38     61 %    18.47 %
# India            -532687.0       2.2      28     35 %    17.70 %
# United States     954806.0       1.8      38     83 %     4.25 %
# Indonesia         -98955.0       2.3      30     56 %     3.51 %
# Pakistan         -233379.0       3.6      23     35 %     2.83 %
# ...                    ...       ...     ...      ...        ...
# Montserrat             0.0         0       0     10 %     0.00 %
# Falkland Islands       0.0         0       0     66 %     0.00 %
# Niue                   0.0         0       0     46 %     0.00 %
# Tokelau                0.0         0       0      0 %     0.00 %
# Vatican State          0.0         0       0     N.A.     0.00 %
#
# [235 rows x 10 columns]

# %%
for col in data.columns:
    fixNA(col, 0)

# %%
data
# Out:
#                          Pop YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776       0.39 %    5540090      153  9388211
# India             1380004385       0.99 %   13586631      464  2973190
# United States      331002651       0.59 %    1937734       36  9147420
# Indonesia          273523615       1.07 %    2898047      151  1811570
# Pakistan           220892340       2.00 %    4327022      287   770880
# ...                      ...          ...        ...      ...      ...
# Montserrat              4992       0.06 %          3       50      100
# Falkland Islands        3480       3.05 %        103        0    12170
# Niue                    1626       0.68 %         11        6      260
# Tokelau                 1357       1.27 %         17      136       10
# Vatican State            801       0.25 %          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China            -348399.0       1.7      38     61 %    18.47 %
# India            -532687.0       2.2      28     35 %    17.70 %
# United States     954806.0       1.8      38     83 %     4.25 %
# Indonesia         -98955.0       2.3      30     56 %     3.51 %
# Pakistan         -233379.0       3.6      23     35 %     2.83 %
# ...                    ...       ...     ...      ...        ...
# Montserrat             0.0         0       0     10 %     0.00 %
# Falkland Islands       0.0         0       0     66 %     0.00 %
# Niue                   0.0         0       0     46 %     0.00 %
# Tokelau                0.0         0       0      0 %     0.00 %
# Vatican State          0.0         0       0        0     0.00 %
#
# [235 rows x 10 columns]

# %% [markdown]
# #### Prozente

# %%
data["YearlyChange"].replace(" %", "", regex=True)
# Out:
# Country
# China               0.39
# India               0.99
# United States       0.59
# Indonesia           1.07
# Pakistan            2.00
#                     ...
# Montserrat          0.06
# Falkland Islands    3.05
# Niue                0.68
# Tokelau             1.27
# Vatican State       0.25
# Name: YearlyChange, Length: 235, dtype: object

# %%
data["YearlyChange"] = data["YearlyChange"].replace(" %", "", regex=True)

# %%
data
# Out:
#                          Pop YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776         0.39    5540090      153  9388211
# India             1380004385         0.99   13586631      464  2973190
# United States      331002651         0.59    1937734       36  9147420
# Indonesia          273523615         1.07    2898047      151  1811570
# Pakistan           220892340         2.00    4327022      287   770880
# ...                      ...          ...        ...      ...      ...
# Montserrat              4992         0.06          3       50      100
# Falkland Islands        3480         3.05        103        0    12170
# Niue                    1626         0.68         11        6      260
# Tokelau                 1357         1.27         17      136       10
# Vatican State            801         0.25          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China            -348399.0       1.7      38     61 %    18.47 %
# India            -532687.0       2.2      28     35 %    17.70 %
# United States     954806.0       1.8      38     83 %     4.25 %
# Indonesia         -98955.0       2.3      30     56 %     3.51 %
# Pakistan         -233379.0       3.6      23     35 %     2.83 %
# ...                    ...       ...     ...      ...        ...
# Montserrat             0.0         0       0     10 %     0.00 %
# Falkland Islands       0.0         0       0     66 %     0.00 %
# Niue                   0.0         0       0     46 %     0.00 %
# Tokelau                0.0         0       0      0 %     0.00 %
# Vatican State          0.0         0       0        0     0.00 %
#
# [235 rows x 10 columns]

# %%
def fixPct(col: str):
    data[col] = data[col].replace(" %", "", regex=True)

# %%
for col in data.columns:
    fixPct(col)

# %%
data
# Out:
#                          Pop YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776         0.39    5540090      153  9388211
# India             1380004385         0.99   13586631      464  2973190
# United States      331002651         0.59    1937734       36  9147420
# Indonesia          273523615         1.07    2898047      151  1811570
# Pakistan           220892340         2.00    4327022      287   770880
# ...                      ...          ...        ...      ...      ...
# Montserrat              4992         0.06          3       50      100
# Falkland Islands        3480         3.05        103        0    12170
# Niue                    1626         0.68         11        6      260
# Tokelau                 1357         1.27         17      136       10
# Vatican State            801         0.25          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China            -348399.0       1.7      38       61      18.47
# India            -532687.0       2.2      28       35      17.70
# United States     954806.0       1.8      38       83       4.25
# Indonesia         -98955.0       2.3      30       56       3.51
# Pakistan         -233379.0       3.6      23       35       2.83
# ...                    ...       ...     ...      ...        ...
# Montserrat             0.0         0       0       10       0.00
# Falkland Islands       0.0         0       0       66       0.00
# Niue                   0.0         0       0       46       0.00
# Tokelau                0.0         0       0        0       0.00
# Vatican State          0.0         0       0        0       0.00
#
# [235 rows x 10 columns]

# %% [markdown]
# #### Datentypen

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, China to Vatican State
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pop           235 non-null    int64
#  1   YearlyChange  235 non-null    object
#  2   NetChange     235 non-null    int64
#  3   Density       235 non-null    int64
#  4   Area          235 non-null    int64
#  5   Migrants      235 non-null    float64
#  6   Fert.Rate     235 non-null    object
#  7   Med.Age       235 non-null    object
#  8   UrbanPct      235 non-null    object
#  9   WorldShare    235 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 28.3+ KB

# %%
data = data.convert_dtypes()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, China to Vatican State
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pop           235 non-null    Int64
#  1   YearlyChange  235 non-null    string
#  2   NetChange     235 non-null    Int64
#  3   Density       235 non-null    Int64
#  4   Area          235 non-null    Int64
#  5   Migrants      235 non-null    Int64
#  6   Fert.Rate     235 non-null    object
#  7   Med.Age       235 non-null    object
#  8   UrbanPct      235 non-null    object
#  9   WorldShare    235 non-null    string
# dtypes: Int64(5), object(3), string(2)
# memory usage: 29.4+ KB

# %%
data["YearlyChange"] = data["YearlyChange"].astype(np.float32)

# %%
data
# Out:
#                          Pop  YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776          0.39    5540090      153  9388211
# India             1380004385          0.99   13586631      464  2973190
# United States      331002651          0.59    1937734       36  9147420
# Indonesia          273523615          1.07    2898047      151  1811570
# Pakistan           220892340          2.00    4327022      287   770880
# ...                      ...           ...        ...      ...      ...
# Montserrat              4992          0.06          3       50      100
# Falkland Islands        3480          3.05        103        0    12170
# Niue                    1626          0.68         11        6      260
# Tokelau                 1357          1.27         17      136       10
# Vatican State            801          0.25          2     2003        0
#
#                   Migrants Fert.Rate Med.Age UrbanPct WorldShare
# Country
# China              -348399       1.7      38       61      18.47
# India              -532687       2.2      28       35      17.70
# United States       954806       1.8      38       83       4.25
# Indonesia           -98955       2.3      30       56       3.51
# Pakistan           -233379       3.6      23       35       2.83
# ...                    ...       ...     ...      ...        ...
# Montserrat               0         0       0       10       0.00
# Falkland Islands         0         0       0       66       0.00
# Niue                     0         0       0       46       0.00
# Tokelau                  0         0       0        0       0.00
# Vatican State            0         0       0        0       0.00
#
# [235 rows x 10 columns]

# %%
def fixType(col: str, newType):
    data[col] = data[col].astype(newType)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, China to Vatican State
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pop           235 non-null    Int64
#  1   YearlyChange  235 non-null    float32
#  2   NetChange     235 non-null    Int64
#  3   Density       235 non-null    Int64
#  4   Area          235 non-null    Int64
#  5   Migrants      235 non-null    Int64
#  6   Fert.Rate     235 non-null    object
#  7   Med.Age       235 non-null    object
#  8   UrbanPct      235 non-null    object
#  9   WorldShare    235 non-null    string
# dtypes: Int64(5), float32(1), object(3), string(1)
# memory usage: 28.5+ KB

# %%
fixType("Pop", np.int32)

# %%
fixType("NetChange", np.int32)

# %%
fixType("Density", np.int16)

# %%
fixType("Area", np.int32)

# %%
fixType("Migrants", np.int32)

# %%
fixType("Fert.Rate", np.float32)

# %%
fixType("Med.Age", np.int8)

# %%
fixType("UrbanPct", np.float32)

# %%
fixType("WorldShare", np.float32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, China to Vatican State
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Pop           235 non-null    int32
#  1   YearlyChange  235 non-null    float32
#  2   NetChange     235 non-null    int32
#  3   Density       235 non-null    int16
#  4   Area          235 non-null    int32
#  5   Migrants      235 non-null    int32
#  6   Fert.Rate     235 non-null    float32
#  7   Med.Age       235 non-null    int8
#  8   UrbanPct      235 non-null    float32
#  9   WorldShare    235 non-null    float32
# dtypes: float32(4), int16(1), int32(4), int8(1)
# memory usage: 18.0+ KB

# %% [markdown]
# #### Neue Spalten hinzufügen

# %%
data["Pop/Area"] = data["Pop"] / data["Area"]

# %%
data
# Out:
#                          Pop  YearlyChange  NetChange  Density     Area  \
# Country
# China             1439323776          0.39    5540090      153  9388211
# India             1380004385          0.99   13586631      464  2973190
# United States      331002651          0.59    1937734       36  9147420
# Indonesia          273523615          1.07    2898047      151  1811570
# Pakistan           220892340          2.00    4327022      287   770880
# ...                      ...           ...        ...      ...      ...
# Montserrat              4992          0.06          3       50      100
# Falkland Islands        3480          3.05        103        0    12170
# Niue                    1626          0.68         11        6      260
# Tokelau                 1357          1.27         17      136       10
# Vatican State            801          0.25          2     2003        0
#
#                   Migrants  Fert.Rate  Med.Age  UrbanPct  WorldShare  \
# Country
# China              -348399        1.7       38      61.0   18.469999
# India              -532687        2.2       28      35.0   17.700001
# United States       954806        1.8       38      83.0    4.250000
# Indonesia           -98955        2.3       30      56.0    3.510000
# Pakistan           -233379        3.6       23      35.0    2.830000
# ...                    ...        ...      ...       ...         ...
# Montserrat               0        0.0        0      10.0    0.000000
# Falkland Islands         0        0.0        0      66.0    0.000000
# Niue                     0        0.0        0      46.0    0.000000
# Tokelau                  0        0.0        0       0.0    0.000000
# Vatican State            0        0.0        0       0.0    0.000000
#
#                     Pop/Area
# Country
# China             153.311827
# India             464.149410
# United States      36.185356
# Indonesia         150.987053
# Pakistan          286.545688
# ...                      ...
# Montserrat         49.920000
# Falkland Islands    0.285949
# Niue                6.253846
# Tokelau           135.700000
# Vatican State            inf
#
# [235 rows x 11 columns]

# %%
data.to_csv("Data/PopulationDataFertig.csv")
