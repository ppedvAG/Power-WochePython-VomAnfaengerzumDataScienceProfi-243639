# %% [markdown]
# ## Matplotlib
#
# Das Hauptwerkzeug zur Darstellung von Daten
#
# Pandas hat eine Integration von Matplotlib
#
# https://matplotlib.org/stable/plot_types/index.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  # WICHTIG: Hier pyplot importieren

# %%
data = pd.read_csv("Data/AmazonStock.csv", index_col="Date", parse_dates=True)

# %%
data
# Out:
#                   Open        High        Low       Close   Adj Close  \
# Date
# 2013-03-25   12.929000   12.971500  12.725000   12.801000   12.801000
# 2013-03-26   12.852500   13.074000  12.814000   13.015500   13.015500
# 2013-03-27   12.937500   13.296500  12.895000   13.265000   13.265000
# 2013-03-28   13.291000   13.369000  13.203000   13.324500   13.324500
# 2013-04-01   13.349000   13.370000  13.050500   13.080500   13.080500
# ...                ...         ...        ...         ...         ...
# 2023-03-20   98.410004   98.480003  95.699997   97.709999   97.709999
# 2023-03-21   98.139999  100.849998  98.000000  100.610001  100.610001
# 2023-03-22  100.449997  102.099998  98.610001   98.699997   98.699997
# 2023-03-23  100.430000  101.059998  97.620003   98.709999   98.709999
# 2023-03-24   98.070000   98.300003  96.400002   98.129997   98.129997
#
#               Volume
# Date
# 2013-03-25  50278000
# 2013-03-26  48420000
# 2013-03-27  57498000
# 2013-03-28  49474000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2519 entries, 2013-03-25 to 2023-03-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2519 non-null   float64
#  1   High       2519 non-null   float64
#  2   Low        2519 non-null   float64
#  3   Close      2519 non-null   float64
#  4   Adj Close  2519 non-null   float64
#  5   Volume     2519 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 137.8 KB

# %% [markdown]
# ### Plotten mit Pandas

# %%
data.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.drop(columns=["Volume"]).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data["Open"].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Über Matplotlib selbst

# %%
plt.figure(figsize=(12, 3))
plt.plot(data["Open"])
plt.title("Open Price")
plt.xlabel("Year")
plt.ylabel("Price ($)")
plt.show()

# %% [markdown]
# ### Globaler vs. Objektorientiert Modus
#
# Beim Globalen Modus wird der Graph über die plt. Methoden konfiguriert und im Anschluss angezeigt
#
# Beim Objektorientierten Modus haben wir Zugriff auf die einzelnen Plots & Achsen und können diese separat konfigurieren

# %% [markdown]
# #### Beispiel Globaler Modus

# %%
plt.figure(figsize=(12, 3))
plt.plot(data["Open"])
plt.title("Open Price")
plt.xlabel("Year")
plt.ylabel("Price ($)")
plt.show()  # Plot beenden


plt.figure(figsize=(12, 3))
plt.plot(data["Close"])
plt.title("Close Price")
plt.xlabel("Year")
plt.ylabel("Price ($)")
# Out:
# Text(0, 0.5, 'Price ($)')

# %% [markdown]
# #### Beispiel Objektorientierter Modus

# %%
figure, ((plot1_1, plot1_2), (plot2_1, plot2_2)) = plt.subplots(2, 2, figsize=(12, 4))  # Rückgabewert: Figure selbst (das Ganze) + die 4 Plots separat

plot1_1.plot(np.random.random(100), color="Red")
plot1_1.set_title("Rote Linie")

plot1_2.plot(np.random.random(100), color="Green")
plot1_2.set_title("Grüne Linie")

plot2_1.plot(np.random.random(100), color="Blue")
plot2_1.set_title("Blue Linie")

plot2_2.plot(np.random.random(100), color="Yellow")
plot2_2.set_title("Gelbe Linie")
# Out:
# Text(0.5, 1.0, 'Gelbe Linie')

# %% [markdown]
# ### Beispielsdiagramme

# %% [markdown]
# #### Balkendiagramm

# %%
data = pd.read_csv("Data/PopulationDataFertig.csv")

# %%
data
# Out:
#               Country         Pop  YearlyChange  NetChange  Density     Area  \
# 0               China  1439323776          0.39    5540090      153  9388211
# 1               India  1380004385          0.99   13586631      464  2973190
# 2       United States   331002651          0.59    1937734       36  9147420
# 3           Indonesia   273523615          1.07    2898047      151  1811570
# 4            Pakistan   220892340          2.00    4327022      287   770880
# ..                ...         ...           ...        ...      ...      ...
# 230        Montserrat        4992          0.06          3       50      100
# 231  Falkland Islands        3480          3.05        103        0    12170
# 232              Niue        1626          0.68         11        6      260
# 233           Tokelau        1357          1.27         17      136       10
# 234     Vatican State         801          0.25          2     2003        0
#
# ...

# %%
plt.figure(figsize=(12, 4))
plt.bar(data.loc[:10, "Country"], data.loc[:10, "Pop"], color="Red", edgecolor="black")
plt.grid(alpha=0.2, linestyle="--")
plt.xticks(rotation=45)
None  # Rückgabewertausgabe unterdrücken

# %%
plt.figure(figsize=(12, 4))
plt.barh(data.loc[:10, "Country"], data.loc[:10, "Pop"], color="Green")
plt.grid(alpha=0.2, linestyle="--")

# %% [markdown]
# #### Histogramm
#
# = Verteilungsdiagramm

# %%
plt.hist(data["Med.Age"], np.arange(15, 50), edgecolor="black", color="yellow")
None

# %% [markdown]
# #### Tortendiagramm
#
# = Kreisdiagramm

# %%
plt.figure(figsize=(10, 10))
plt.pie(data.loc[:5, "WorldShare"], labels=data.loc[:5, "Country"], rotatelabels=True, labeldistance=0.4, wedgeprops={"linewidth": 1, "edgecolor": "black"})
plt.savefig("Test.png")
None

# %% [markdown]
# #### Streudiagramm
#
# Zeigt die Verteilung von Punkten an

# %%
plt.figure(figsize=(12, 6))
points = np.random.randint(10000, size=(100, 100))
plt.scatter(points[0], points[1], c=points[0] * points[1], s=(points[0] * points[1]) / 50000)
None
